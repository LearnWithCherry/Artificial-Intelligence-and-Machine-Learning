# %%
import pandas as pd
import numpy as np

# %%
data = {
    "Name": ["Aman", "Riya", "Ankita", "Neha"],
    "Age": [21, 22, 23, 24],
    "Marks": [50, 90, 99, 88]
}

df = pd.DataFrame(data)

# %%
df.head(2)
# Out:
#    Name  Age  Marks
# 0  Aman   21     85
# 1  Riya   22     90

# %%
df["Name"]
# Out:
# 0      Aman
# 1      Riya
# 2    Ankita
# 3      Neha
# Name: Name, dtype: object

# %%
df["Marks"] >= 80
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# Name: Marks, dtype: bool

# %%
df["Marks"].mean()
# Out:
# np.float64(81.75)

# %%
df.iloc[2]
# Out:
# Name     Ankita
# Age          23
# Marks        99
# Name: 2, dtype: object

# %%
df["Result"] = df["Marks"] >= 80
df
# Out:
#      Name  Age  Marks  Result
# 0    Aman   21     50   False
# 1    Riya   22     90    True
# 2  Ankita   23     99    True
# 3    Neha   24     88    True

# %%
df = df.sort_values(by="Marks", ascending=False)
df
# Out:
#      Name  Age  Marks  Result
# 2  Ankita   23     99    True
# 1    Riya   22     90    True
# 3    Neha   24     88    True
# 0    Aman   21     50   False
