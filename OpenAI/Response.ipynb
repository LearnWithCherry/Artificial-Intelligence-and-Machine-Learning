# %%
API_openAi = "KEY"

# %%
# !python -m pip install openai

# %%
from openai import OpenAI

client = OpenAI(api_key=API_openAI)

response = client.responses.create(
    model="gpt-5.6",
    input="Write a poem about unicorn."),

print(response.output_text)
