# %%
from openai import OpenAI

API_openrouter = "API"
client = OpenAI(
    api_key=API_openrouter,
    base_url="https://openrouter.ai/api/v1"
)

# %%
# !python -m pip install openai

# %%
response = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {
            "role": "user",
            "content": "Write a short poem about a unicorn."
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# In the hush of twilight’s velvet,
# a silver unicorn appears,
# its horn a shimmering crescent,
# whispering of hidden tears.
#
# It gallops through a dreamscape,
# leaves sparkle on the pale wind’s path,
# a living lullaby of wonder,
# where myths and hopes dance in that.
