# %%
# You are hired as a ML Engineer to build classification models using:
# •K-NearestNeighbours(KNN) 
# •LogisticRegression
# •NaiveBayes
# Your task is to train all three models, compare their performances, and identify the best algorithm.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score
import pandas as pd
import time

# %%
data = pd.read_csv("X:\\VScode\\Artificial_intelligence_n_Machine_learning\\Supervised_Learning\\Iris.csv")

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# No need to process the data as it is all ready in proper from

# %% [markdown]
# # LogisticRegression

# %%
X = data.drop("Species",axis=1)
y = data["Species"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

model_LR = LogisticRegression(max_iter=1000)
model_LR.fit(X_train,y_train)

y_pred = model_LR.predict(X_test)

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred, average='weighted'))
print("Recall   :", recall_score(y_test, y_pred, average='weighted'))
print("F1 Score :", f1_score(y_test, y_pred, average='weighted'))
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy : 1.0
# Precision: 1.0
# Recall   : 1.0
# F1 Score : 1.0
# Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        15
#  Iris-virginica       1.00      1.00      1.00        16
#
#        accuracy                           1.00        50
#       macro avg       1.00      1.00      1.00        50
#    weighted avg       1.00      1.00      1.00        50

# %% [markdown]
# # KNN Model

# %%
X = data.drop("Species",axis=1)
y = data["Species"]
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

model_KK = KNeighborsClassifier(n_neighbors=3)
model_KK.fit(X_train,y_train)

y_pred = model_KK.predict(X_test)

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred, average='weighted'))
print("Recall   :", recall_score(y_test, y_pred, average='weighted'))
print("F1 Score :", f1_score(y_test, y_pred, average='weighted'))
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy : 1.0
# Precision: 1.0
# Recall   : 1.0
# F1 Score : 1.0
# Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        15
#  Iris-virginica       1.00      1.00      1.00        16
#
#        accuracy                           1.00        50
#       macro avg       1.00      1.00      1.00        50
#    weighted avg       1.00      1.00      1.00        50

# %%
X = data.drop("Species",axis=1)
y = data["Species"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

model_GB = GaussianNB()
model_GB.fit(X_train,y_train)

y_pred = model_GB.predict(X_test)

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred, average='weighted'))
print("Recall   :", recall_score(y_test, y_pred, average='weighted'))
print("F1 Score :", f1_score(y_test, y_pred, average='weighted'))
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy : 1.0
# Precision: 1.0
# Recall   : 1.0
# F1 Score : 1.0
# Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        15
#  Iris-virginica       1.00      1.00      1.00        16
#
#        accuracy                           1.00        50
#       macro avg       1.00      1.00      1.00        50
#    weighted avg       1.00      1.00      1.00        50

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "KNN": KNeighborsClassifier(n_neighbors=5),
    "Naive Bayes": GaussianNB()
}

results = []

for name, model in models.items():

    start = time.time()
    model.fit(X_train, y_train)
    train_time = time.time() - start

    y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)

    cv_score = cross_val_score(model, X, y, cv=5).mean()

    results.append({
        "Model": name,
        "Accuracy": accuracy,
        "Cross Validation": cv_score,
        "Training Time": train_time
    })

results = pd.DataFrame(results)
print(results.sort_values(by="Cross Validation", ascending=False))
# Out:
#                  Model  Accuracy  Cross Validation  Training Time
# 2          Naive Bayes       1.0          0.993333       0.000965
# 0  Logistic Regression       1.0          0.880000       0.029924
# 1                  KNN       1.0          0.873333       0.000894

# %% [markdown]
# All three algorithms (KNN, Logistic Regression, and Naive Bayes) achieved 100% accuracy, precision, recall, and F1-score on the Iris dataset. Since their predictive performance is identical, Logistic Regression can be selected because it is simple, fast, and highly interpretable. Alternatively, KNN or Naive Bayes are also valid choices for this dataset.

# %% [markdown]
#  | Model               | Accuracy | Precision | Recall | F1   |
# # | ------------------- | -------- | --------- | ------ | ---- |
# # | KNN                 | 1.00     | 1.00      | 1.00   | 1.00 |
# # | Logistic Regression | 1.00     | 1.00      | 1.00   | 1.00 |
# # | Naive Bayes         | 1.00     | 1.00      | 1.00   | 1.00 |
