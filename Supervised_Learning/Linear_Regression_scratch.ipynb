# %%
import numpy as np

# %%
class LinearRegression:
    def __init__(self, learningRate = 0.1, n_iter=1000):
        self.bias = None
        self.weight = None
        self.learningRate = learningRate
        self.n_iter = n_iter

    def fit(self, X, y):
        m, n = X.shape
        self.bias = 0
        self.weight = np.zeros(n)
        for i in range(self.n_iter):
            y_pred = self.bias + np.dot(X, self.weight)
            db = (1/m) * np.sum(y_pred - y)
            dw = (1/w) * np.dot(X.T, y_pred - y)
            self.bias -= self.learningRate * db
            self.weight -= self.lr * dw

    def predict(self, X):
        y_pred = self.bias + np.dot(X, self.weight)
        return y_pred

# %%
LinearRegression()

# %%
X = np.array([[1],[2],[3],[4],[5]])
y = np.array([2, 4, 6, 8, 10])

model = LinearRegression()
model.fit(X,y)

y_pred = model.predict(X)
print(y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       2 y = np.array([2, 4, 6, 8, 10])
#       4 model = LinearRegression()
# ----> 5 model.fit(X,y)
#       7 y_pred = model.predict(X)
#       8 print(y_pred)
#
# Cell In[5], line 15, in LinearRegression.fit(self, X, y)
#      13 y_pred = self.bias + np.dot(X, self.weight)
#      14 db = (1/m) * np.sum(y_pred - y)
# ---> 15 dw = (1/w) * np.dot(X.T, y_pred - y)
#      16 self.bias -= self.learningRate * db
#      17 self.weight -= self.lr * dw
#
# NameError: name 'w' is not defined
