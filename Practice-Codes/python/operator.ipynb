# %%
# operator

# %%
10 / 3   # 3.333...
10 // 3  # 3
10 % 3   # 1
2 ** 3   # 8
# Out:
# 8

# %%
x = 5
y = 2

print(x / y)
print(x // y)
print(x % y)
print(x ** y)
# Out:
# 2.5
# 2
# 1
# 25

# %%
# 🔹 Basic Order (Simplified)

# Highest → Lowest:

# ** (power)

# * / // %

# + -

# Comparison operators (> < == !=)

# not

# and

# or

# %%
2 + 3 * 4
'''
3 * 4 = 12
2 + 12 = 14

Result: 14
'''
# Out:
# '\n3 * 4 = 12\n2 + 12 = 14\n\nResult: 14\n'
