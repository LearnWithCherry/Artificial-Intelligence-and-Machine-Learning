# %%
# Tuple (Immutable Ordered Collection)
# A tuple is:

    # Ordered
    
    # Immutable (cannot change after creation)
    
    # Allows duplicates
    
    # Can store mixed data types

    # Denoted with "()"

# %%
t = (10, 20, 30)
mixed = (1, "Cherry", True, 3.14)

# %%
t = [1,2,3,4,5]
t[0]
t[-1]
t[0:2]
# Out:
# [1, 2]

# %%
# Immutability
# t[1] = 200 | this will fail when executed

# %%
# Method in Tuple

# %%
t1 = (1,2,3,4,5,6,7,7)
t1.count(7)
# Out:
# 2

# %%
# declare single tuple
t2 = (1,)
t3 = (1) #this is a int not a list
print(type(t2))
print(type(t3))
# Out:
# <class 'tuple'>
# <class 'int'>

# %%
t = (1,2,2,3)
t.count(2)

# %%
# Tuple packing and unpacking 

t = 1,2,3
a,b,c = t

print(a)

x,y = 12,23
print(x)
# Out:
# 1
# 12

# %%
t = (1, [2,3])
t[1].append(4)
# Tuple itself is immutable.
# But if it contains a list:

# %%
# program

tuple_new = (1,2,3,4)
tuple_new.index(2)
tuple_new.count(2)

a,b,c,d = tuple_new
print(a)
# Out:
# 1
