# %%
import pandas as pd

df = pd.read_csv("x://VScode//jupyter_lab//Pandas//globalAirQuality.csv")

# %%
#access columns
df["aqi"]
df[["city","aqi"]] #case senestive values 
# to access 2 or more values at once this is how we can do this 
#
# Out:
#            city  aqi
# 0      New York  108
# 1      New York   90
# 2      New York   84
# 3      New York  158
# 4      New York   97
# ...         ...  ...
# 17995    Zurich  103
# 17996    Zurich  105
# 17997    Zurich  122
# 17998    Zurich   95
# 17999    Zurich   88
#
# [18000 rows x 2 columns]

# %%
# access indivisual cells
df.loc[0,"aqi"]
# Out:
# np.int64(108)

# %%
# access rows
df.loc[2]
df.loc[0:2] # start idx : end idx

df.iloc[2]
df.iloc[0:2] # start idx : end idx
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
#
#    wind_speed
# 0       3.725
# 1       8.969

# %%
df.loc[0:3,["city","aqi"]]
# Out:
#        city  aqi
# 0  New York  108
# 1  New York   90
# 2  New York   84
# 3  New York  158

# %%
df.iloc[0:3,2]
# Out:
# 0    New York
# 1    New York
# 2    New York
# Name: city, dtype: object

# %%
df.iloc[0:3,5]
# Out:
# 0    50.295
# 1    32.083
# 2    42.250
# Name: pm25, dtype: float64

# %%
df.iloc[0:3, 0:7]
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
#
#       pm10
# 0  108.938
# 1   63.043
# 2   82.553

# %%
# cell

df.at[0, "city"]
# Out:
# 'New York'

# %%
df.iat[0,2]
# Out:
# 'New York'

# %%
cities = df["city"]
cities[0] = "New York" # working on original data
df
# Out:
# C:\Users\Rajat Bhardwaj\AppData\Local\Temp\ipykernel_5256\1056323918.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cities[0] = "New York" # working on original data
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# ...

# %%
cities = df["city"].copy() # working on a copy data original data does not get affected
cities[0] = "New York"

# %%
# Filtering data

df[df["aqi"] > 100]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 6      2025-11-05 00:25:17.554219      US  New York    40.713    -74.006
# 7      2025-11-05 01:25:17.554219      US  New York    40.713    -74.006
# 8      2025-11-05 02:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17991  2025-11-19 09:25:17.554219      CH    Zurich    47.377      8.542
# 17993  2025-11-19 11:25:17.554219      CH    Zurich    47.377      8.542
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df[(df["aqi"] > 100) & (df["temperature"] > 30)][["city","aqi","temperature"]]
# Out:
#            city  aqi  temperature
# 6      New York  155       36.729
# 7      New York  115       37.891
# 14     New York  121       34.481
# 17     New York  127       36.193
# 25     New York  113       31.289
# ...         ...  ...          ...
# 17947    Zurich  107       32.584
# 17950    Zurich  140       36.885
# 17975    Zurich  111       30.761
# 17976    Zurich  146       30.909
# 17991    Zurich  104       32.556
#
# [2384 rows x 3 columns]
