# %%
# !pip install flask
# Out:
# Collecting flask
#   Downloading flask-3.1.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: blinker>=1.9.0 in X:\AnacondaFiles\envs\ml_env\Lib\site-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in X:\AnacondaFiles\envs\ml_env\Lib\site-packages (from flask) (8.4.2)
# Requirement already satisfied: itsdangerous>=2.2.0 in X:\AnacondaFiles\envs\ml_env\Lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in X:\AnacondaFiles\envs\ml_env\Lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in X:\AnacondaFiles\envs\ml_env\Lib\site-packages (from flask) (3.0.3)
# Collecting werkzeug>=3.1.0 (from flask)
#   Downloading werkzeug-3.1.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: colorama in X:\AnacondaFiles\envs\ml_env\Lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Downloading flask-3.1.3-py3-none-any.whl (103 kB)
# Downloading werkzeug-3.1.8-py3-none-any.whl (226 kB)
# Installing collected packages: werkzeug, flask
#
#    ---------------------------------------- 0/2 [werkzeug]
#    ---------------------------------------- 0/2 [werkzeug]
#    ---------------------------------------- 0/2 [werkzeug]
#    -------------------- ------------------- 1/2 [flask]
#    -------------------- ------------------- 1/2 [flask]
#    ---------------------------------------- 2/2 [flask]
#
# Successfully installed flask-3.1.3 werkzeug-3.1.8

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def home():
    return "Hello! Flask is working 🎉"

@app.route("/hello")
def hello():
    return "Hello from Flask!"

app.run(host="127.0.0.1", port=5000, debug=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [02/Sep/2026 19:48:50] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Sep/2026 19:48:50] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [02/Sep/2026 19:49:07] "GET / HTTP/1.1" 200 -
